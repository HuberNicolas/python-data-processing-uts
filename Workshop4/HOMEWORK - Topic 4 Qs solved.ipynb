# %%
#1.  Let google colab have an access to the file in your drive
#from google.colab import drive
#drive.mount('/content/drive/')

# %%
#2. Insert the home directory where you store your custom python module
#import sys
#sys.path.insert(0,'/content/drive/My Drive/Week 4')

# %%
# Topic: Create and Use Python Modules

# Question 1: Create a Python module named 'calculator' that includes functions for addition and subtraction.
# Your code here

from calculator import add, subtract, square_root, is_even

# %%
# Answer 1:
# create calculator.py as below and upload it to google drive "week 4" folder if you are using Colab

# %%
# Question 2: Use the 'add' and 'subtract' functions from the 'calculator' module to perform operations (e.g., 10 + 5 and 8 - 3).
# Your code here


print("Results of addition is: ", add(10, 5))
print("Results of subtraction is: ", subtract(8, 3))
# Out:
# Results of addition is:  15
# Results of subtraction is:  5

# %%
# Answer 2:
# main.py

# %%
# Question 3: calculator.py, add a function to calculate the square root (power of 0.5) and a function to chreck if hte number is even
#complete the code
import math

print("Results of the power function is: ", square_root(5))
check_number = 17
print(f"The number {check_number} is even: {is_even(check_number)} ")
# Out:
# Results of the power function is:  2.23606797749979
# The number 17 is even: False

# %%
# Question 4: Use the 'datetime' library to calculate the difference between two dates and display the result.

# %%
# Answer 10:
# main.py

from datetime import datetime, timedelta

# Sample dates
date1 = datetime(2023, 1, 1)
date2 = datetime(2023, 12, 31)

# Calculate the difference
date_difference = date2 - date1

print(f"The difference between {date2} and {date1} is:", date_difference)
# Out:
# The difference between 2023-12-31 00:00:00 and 2023-01-01 00:00:00 is: 364 days, 0:00:00

# %%
#Question 5
#Use random function to create a random decimal number between 5 and 6

import random


random_int = random.randint(a=5, b=6)
print("Random float between 5 and 6:", random_int)
# Out:
# Random float between 5 and 6: 5
