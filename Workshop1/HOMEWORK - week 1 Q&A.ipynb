# %%
# Python Q&A Notebook

# Topic: The print function

# Question 1: How do you use the print function to display the text "Welcome to Python!"?
# Your code here

# Answer 1:
print("Answer 1: To display 'Welcome to Python!' in Python, you can use: print('Welcome to Python!')")


# Topic: Basic arithmetic operations

# Question 2: Calculate the sum of 15 and 7.
# Your code here

# Answer 2:
num1 = 15
num2 = 7
sum_result = num1 + num2
print("Answer 2: The sum of {} and {} is {}".format(num1, num2, sum_result))


# Question 3: Calculate the product of 5 and 8.
# Your code here

# Answer 3:
num3 = 5
num4 = 8
product_result = num3 * num4
print("Answer 3: The product of {} and {} is {}".format(num3, num4, product_result))


# Question 4: Find the remainder when 20 is divided by 3.
# Your code here

# Answer 4:
num5 = 20
num6 = 3
remainder_result = num5 % num6
print("Answer 4: The remainder when {} is divided by {} is {}".format(num5, num6, remainder_result))


# Question 5: Calculate 2 raised to the power of 5.
# Your code here

# Answer 5:
base = 2
exponent = 5
power_result = base ** exponent
print("Answer 5: {} raised to the power of {} is {}".format(base, exponent, power_result))


# Topic: Variables from different data types

# Question 6: Create a variable named 'city' with the value "New York".
# Your code here

# Answer 6:
city = "New York"
print("Answer 6: The value of city is '{}'".format(city))


# Question 7: Create a variable named 'pi_value' with the value 3.14159.
# Your code here

# Answer 7:
pi_value = 3.14159
print("Answer 7: The value of pi_value is {}".format(pi_value))


# Topic: Python comparison operators

# Question 8: Check if the value of 'temperature' is less than or equal to 32.
# Your code here

# Answer 8:
temperature = 28
is_below_freezing = temperature <= 32
print("Answer 8: Is the temperature below or equal to 32? {}".format(is_below_freezing))
