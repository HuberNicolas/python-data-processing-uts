# %%
# Python Q&A Notebook

# Topic: The print function

# Question 1: How do you use the print function to display the text "Welcome to Python!"?

# Answer 1:
print("Welcome to Python!")


# Topic: Basic arithmetic operations

# Question 2: Calculate the sum of 15 and 7.

# Answer 2:
num1 = 15
num2 = 7
sum_result = num1 + num2
print(f"The sum of the two numbers, {num1} and {num2} is: {sum_result}")


# Question 3: Calculate the product of 5 and 8.
# Your code here

# Answer 3:
num3 = 5
num4 = 8
product_result = num3 * num4
print(f"The product of the two numbers, {num3} and {num4} is: {product_result}")



# Question 4: Find the remainder when 20 is divided by 3.
# Your code here

# Answer 4:
num5 = 20
num6 = 3
reminder = num5 % num6
print(f"The reminder of dividing {num5} by {num6} is: {reminder}")

# Question 5: Calculate 2 raised to the power of 5.


# Answer 5:
base = 2
exponent = 5
power = 2 ** 5
print(f"{base} raised to the power {exponent} is: {power}")

# Topic: Variables from different data types

# Question 6: Create a variable named 'city' with the value "New York".

# Answer 6:
city = "New York"

# Question 7: Create a variable named 'pi_value' with the value 3.14159.

# Answer 7:
pi_value = 3.14159

# Topic: Python comparison operators

# Question 8: Check if the value of 'temperature' is less than or equal to 32.

# Answer 8:
temperature = 28



if temperature <= 32:
    print(f"The value of temperature, which is {temperature}, is less or equal than 32.")
else:
    print(f"The value of temperature, which is {temperature}, is larger than 32.")
# Out:
# Welcome to Python!
# The sum of the two numbers, 15 and 7 is: 22
# The product of the two numbers, 5 and 8 is: 40
# The reminder of dividing 20 by 3 is: 2
# 2 raised to the power 5 is: 32
# The value of temperature, which is 28, is less or equal than 32.
