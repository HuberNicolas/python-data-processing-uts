# %% [markdown]
# The notebook contain at questions about each of these topics
# * define function with and without paramters
# * create OOP classes
# * create objects and call methods

# %%
# Python Q&A Notebook

# Topic: Define Function with Parameters

# Question 1: Define a function named 'greet' that takes a parameter 'name' and prints a greeting.
# Your code here

# %%
# Answer 1:
def greet(name):
    print("Hello, {}! Welcome.".format(name))

# Example usage:
greet("Alice")

# %%
# Question 2: Define a function named 'calculate_area' that takes two parameters 'length' and 'width' and returns the area.
# Your code here

# %%
# Answer 2:
def calculate_area(length, width):
    return length * width

# Example usage:
area_result = calculate_area(5, 3)
print("The area is:", area_result)

# %%
# Topic: Define Function without Parameters

# Question 3: Define a function named 'generate_random_password'
#that prints a random password using some formular of multiplying your year of birth with the number of day this year and concatentate it with the first two letters of your name.
# Your code here

# %%
# Answer 3:
def generate_random_password():
    # Assuming your year of birth is 2000 and the number of days this year is 365
    year_of_birth = 2000
    days_this_year = 365
    name = "John"  # Change this to the first two letters of your name

    # Calculate the random part of the password using the specified formula
    random_part = str(year_of_birth * days_this_year)

    # Concatenate with the first two letters of the name
    random_password = random_part + name[:2]

    print("Random Password:", random_password)

# Example usage:
generate_random_password()

# %%
# Question 4: Define a function named 'say_hello' that prints "Hello, World!" without any parameters.
# Your code here

# %%
# Answer 4:
def say_hello():
    print("Hello, World!")

# Example usage:
say_hello()

# %%
# Topic: Create a Simple Class

# Question 5: Create a class named 'Car' with an __init__ method that initializes 'make' and 'model' attributes.
# Your code here

# %%
# Answer 5:
class Car:
    def __init__(self, make, model):
        self.make = make
        self.model = model

# Example usage:
my_car = Car("Toyota", "Camry")
print("My car: {} {}".format(my_car.make, my_car.model))

# %%
# Question 6: Create a class named 'Rectangle' with methods 'calculate_area' and 'calculate_perimeter'.
# Your code here

# %%
# Answer 6:
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

# Example usage:
my_rectangle = Rectangle(4, 6)
area = my_rectangle.calculate_area()
perimeter = my_rectangle.calculate_perimeter()
print("Rectangle Area:", area)
print("Rectangle Perimeter:", perimeter)
