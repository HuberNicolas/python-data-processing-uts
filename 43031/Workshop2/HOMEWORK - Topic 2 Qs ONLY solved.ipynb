# %%
# Python Q&A Notebook - Set 2

# Topic: Input Function

# Question 1: How do you use the input function to get the tutor's name and print a greeting?
# Your code here

# %%
# Answer 1:

name = input("Please enter you name: ")

print(f"Hello {name}!")
# Out:
# Hello Nicolas!

# %%
# Question 2: Use the input function to get the tutor's age and print a message based on their age.
# Your code here

# %%
# Answer 2:

age = input("Please enter you age: ")

print(f"Hello, {name}, your age is {age}.")
# Out:
# Hello, Nicolas, your age is 27.

# %%
# Topic: Conditional Statements (if, if-else, if-elif-else)

# Question 3: Check if a given mark is fail or pass using if-else statements.
# Your code here

# %%
# Answer 3:

mark = input("Please enter you mark: ")

if int(mark) <= 5:
    print(f"You did not pass because your mark {mark} is not higher than 5.")
else:
    print(f"You did pass because your mark {mark} is greater than 5.")
# Out:
# You did pass because your mark 7 is greater than 5.

# %%
# Question 4: Determine the category of a given temperature using if-elif-else statements.
# Your code here

# %%
# Answer 4:

temp = input("Please enter the current temperature: ")
temp = int(temp)

if temp < 10:
    print("Its a bit chilly today.")
elif temp >= 10 and temp < 20:
    print("Its not warm today.")
else:
    print("Today its quite warm.")
# Out:
# Its a bit chilly today.

# %%
# Topic: Loops (While and For)

# Question 5: Use a loop to ask the tutor to enter the number of employees and their salaries. Calculate the average salary.
# Your code here

# %%
# Answer 5:
print("Answer 5: Using a loop to ask the tutor to enter the number of employees and their salaries. Calculate the average salary:")



salaries = []

while True:
    user_input = input("Please enter a salary: ")
    if user_input == "stop":
        break
    try:
        salary = int(user_input)
        salaries.append(salary)
        print(f"You entered the salary: {salary}")
    except ValueError:
        print("That's not a valid salary!")

print("Your salaries:")
print(salaries)

if len(salaries) != 0:
    avg_salary = sum(salaries) / len(salaries)
    print(f"The average salary is {avg_salary}.")
else:
    print("Not enough data for salary calculation provided.")
# Out:
# Answer 5: Using a loop to ask the tutor to enter the number of employees and their salaries. Calculate the average salary:
# You entered the salary: 5
# You entered the salary: 2
# You entered the salary: 8
# You entered the salary: 12
# You entered the salary: 17
# You entered the salary: 3
# Your salaries:
# [5, 2, 8, 12, 17, 3]
# The average salary is 7.833333333333333.
