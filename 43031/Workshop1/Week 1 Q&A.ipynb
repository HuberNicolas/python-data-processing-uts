# %% [markdown]
# This Python notebook contain questions about each of these topics:
# * The print function
# * Basic arithmetic operations
# * Variables and constants
# * Data types
# * Python operators

# %%
# Python Coding Q&A Notebook

# Topic: The print function

# Coding Question 1: Write a Python code to print your name.
name = "John"
print(name)
# Out:
# John

# %%
# Coding Question 2: Combine two variables, `first_name` and `last_name`, and print the full name.
first_name = "Alice"
last_name = "Smith"
full_name = first_name + " " + last_name
print(full_name)
# Out:
# Alice Smith

# %%
# Topic: Basic arithmetic operations

# Coding Question 3: Calculate the area of a rectangle with length 5 and width 3.
length = 5
width = 3
area = length * width
print("The area of the rectangle is", area)
# Out:
# The area of the rectangle is 15

# %%
# Topic: Basic arithmetic operations

# Coding Question 1: Calculate the sum of two numbers, 8 and 4.
num1 = 8
num2 = 4

# Answer 1:
sum_result = num1 + num2
print("Answer 1: The sum of {} and {} is {}".format(num1, num2, sum_result))
# Out:
# Answer 1: The sum of 8 and 4 is 12

# %%
# Coding Question 2: Find the result of subtracting 15 from 27.
num3 = 27
num4 = 15

# Answer 2:
subtraction_result = num3 - num4
print("Answer 2: The result of subtracting {} from {} is {}".format(num4, num3, subtraction_result))
# Out:
# Answer 2: The result of subtracting 15 from 27 is 12

# %%
# Coding Question 3: Calculate the division of two numbers, 20 and 4.
num5 = 20
num6 = 4
# Your code here

# Answer 3:
division_result = num5 / num6
print("Answer 3: The division of {} by {} is {}".format(num5, num6, division_result))
# Out:
# Answer 3: The division of 20 by 4 is 5.0

# %%
# Coding Question 4: Calculate the square root of 25 using Python.
number = 25
square_root = number**0.5 # ** is the power
print("The square root of 25 is", square_root)
# Out:
# The square root of 25 is 5.0

# %%
# Topic: Variables and constants

# Coding Question 5: Declare a constant named PI with a value of 3.14.
PI = 3.14
print("The value of PI is", PI)
# Out:
# The value of PI is 3.14

# %%
# Coding Question 6: Swap the values of two variables, `a` and `b`.
a = 10
b = 20
a, b = b, a
print("After swapping, a =", a, "and b =", b)
# Out:
# After swapping, a = 20 and b = 10

# %%
# Topic: Data types

# Coding Question 7: three variables with three different data types: integer, float, and string.
age=42
pi=3.14
msg="Hello"
print(age)
print(pi)
print(msg)
# Out:
# 42
# 3.14
# Hello

# %%
# Coding Question 8: Convert the string "123" to an integer in Python.
string_num = "123"
integer_num = int(string_num)
print("The integer value of '123' is", integer_num)
# Out:
# The integer value of '123' is 123

# %%
# Python Comparison Operators Q&A

# Question: Write a Python expression using a comparison operator to check if the value of 'x' is greater than 10.
x = 15
#Answer
is_greater_than_10 = x > 10
print("Answer:", is_greater_than_10)
# Out:
# Answer: True
