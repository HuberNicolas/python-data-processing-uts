# %% [markdown]
# This Python notebook contain questions about each of these topics:
# * The print function
# * Basic arithmetic operations
# * Variables and constants
# * Data types
# * Python operators

# %%
# Python Coding Q&A Notebook

# Topic: The print function

#Write a Python code to print your name.
name = "John"

# %%
print(name)
# Out:
# John

# %%
#Combine two variables, `first_name` and `last_name`, and print the full name.
first_name = "Alice"
last_name = "Smith"

# %%
print(f"{first_name} {last_name}")
# Out:
# Alice Smith

# %%
# Topic: Basic arithmetic operations

#Calculate the area of a rectangle with length 5 and width 3.
length = 5
width = 3

# %%
area_rec = length * width
print(f"The area of the rectangle is: {area_rec}")
# Out:
# The area of the rectangle is: 15

# %%
# Topic: Basic arithmetic operations

#Calculate the sum of two numbers, 8 and 4.
num1 = 8
num2 = 4

# %%
sum = num1 + num2
print(f"The sum of the two numbers, {num1} and {num2} is: {sum}")
# Out:
# The sum of the two numbers, 8 and 4 is: 12

# %%
#Find the result of subtracting 15 from 27.
num3 = 27
num4 = 15

# %%
difference = num3 - num4
print(f"The result of subtracting {num4} from {num3} is: {difference}")
# Out:
# The result of subtracting 15 from 27 is: 12

# %%
#Calculate the division of two numbers, 20 and 4.
num5 = 20
num6 = 4
# Your code here

# %%
quotient = num5 / num6
print(f"The result of dividing {num5} by {num6} from 27 is: {quotient}")
# Out:
# The result of dividing 20 by 4 from 27 is: 5.0

# %%
#Calculate the square root of 25 using Python.
number = 25

# %%
import math
sqrt_root = math.sqrt(number)

print(f"The square root of {number} is: {sqrt_root}")
# Out:
# The square root of 25 is: 5.0

# %%
# Topic: Variables and constants

#Declare a constant named PI with a value of 3.14.

# %%
PI = 3.14

# %%
#Swap the values of two variables, `a` and `b`.
a = 10
b = 20

# %%
print(f"Before swap: value of a: {a}, value of b: {b}")

# Swap
temp = a
a = b
b = temp
print(f"After swap: value of a: {a}, value of b: {b}")
# Out:
# Before swap: value of a: 10, value of b: 20
# After swap: value of a: 20, value of b: 10

# %%
# Topic: Data types

#three variables with three different data types: integer, float, and string.

# %%
#Convert the string "123" to an integer in Python.
string_num = "123"

# %%
int_num = int(string_num)

# %%
# Python Comparison Operators Q&A

#Write a Python expression using a comparison operator to check if the value of 'x' is greater than 10.
x = 15
#Answer

# %%
if x > 10:
    print(f"The value of x, which is {x}, is larger than 10.")
else:
    print(f"The value of x, which is {x}, is not larger than 10.")
# Out:
# The value of x, which is 15, is larger than 10.
