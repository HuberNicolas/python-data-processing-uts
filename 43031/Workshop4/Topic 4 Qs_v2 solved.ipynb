# %% [markdown]
# The notebook contain questions about each of these topics
# * create and use Python modules
# * create and use Python package
# * create and use Python libraries

# %% [markdown]
# **First exercise: Make sure calc.py file is uploaded to Week 4**

# %%
#1.  Let google colab have an access to the file in your drive
#from google.colab import drive
#drive.mount('/content/drive/')

# %%
#2. Insert the home directory where you store your custom python module
#import sys
#sys.path.insert(0,'/content/drive/My Drive/430031 notebooks/Week 4')

# %%
#3. Import your module using a standard Python import statement, but with the path to your module file on Google Drive.
import calc

# %%
#4. use the functions inside the module
result = calc.add(5,10)
print("Results is: ", result)
# Out:
# Results is:  15

# %%
result = calc.subtract(5,10)
print("Results is: ", result)
# Out:
# Results is:  -5

# %%
#5. import specifc functions using the custom module
from calc import add, multiply
# Using the imported functions
result_add = add(5, 3)
print(result_add)

#call multiply functino with paramter values 6 and 3
# Out:
# 8

# %%
# Python Q&A Notebook - Modules
# Question 1: Create a Python module named 'math_operations' that defines a function 'square' to calculate the square of a number.
#Steps:
#1. Create advanced_calc.py file using notepad or any other local editor
#2. add a square function and save the file
#3. upload to custom module tp week 4  google colab

# %%
# Create a code to import advanced_calc.py and print square of 50
from advanced_calc import square

# %%
result_add = square(50)
print(result_add)
# Out:
# 2500

# %%
# Example about built-in functions
import random

# Generate a random integer between 1 and 10 inclusive
random_number = random.randint(1, 10)
print("Random number between 1 and 10:", random_number)

# Generate a random floating-point number between 0 and 1
random_float = random.random()
print("Random float between 0 and 1:", random_float)
# Out:
# Random number between 1 and 10: 3
# Random float between 0 and 1: 0.7472650871288374

# %%
#Generate a integer random number between 1,5
#write the code

rand_number = random.randint(a=1,b=5)
print(f"The random number is {rand_number}.")
# Out:
# The random number is 2.

# %%
#Generate a decimal random number between 1,2
random_decimal = random.uniform(1, 2)
print("Random decimal number between 1 and 2:", random_decimal)
# Out:
# Random decimal number between 1 and 2: 1.913987823580133

# %%
import math

print(math.sqrt(25))       # Output: 5.0
print(math.sin(math.pi/2))  # Output: 1.0 (sine of 90 degrees)
print(math.log(math.e))     # Output: 1.0 (natural logarithm of e)
print(math.pi)              # Output: 3.141592653589793
# Out:
# 5.0
# 1.0
# 1.0
# 3.141592653589793
