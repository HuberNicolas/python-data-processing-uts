# %% [markdown]
# The notebook contain questions about each of these topics:
# * 1D and 2D arrays
# * Read data

# %% [markdown]
# # How to Mount the googledrive to access files?

# %% [markdown]
# Steps to access the files on GoogleDrive:
#
#
# 1.   Upload the files to Drive
# 2.   Mount the drive in GoogleColab using code below
# 3. Access the files

# %%
#Mount the googledrive to access files
from google.colab import drive
drive.mount('/content/drive')
#Path of the file
#'/content/drive/MyDrive/......csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Question 1:
# Create a 1D array in Python. The array contains the characters of the word "Hello".

# %% [markdown]
# Question 2:
# Create a 2D array in Python using a list of lists. The array consists of rows with different data types, including integers, strings, and booleans.

# %%
# Out:
# [[1, 'apple', True], [2, 'banana', False], [3, 'orange', True]]

# %% [markdown]
# Question 3:
# Access elements of a 1D array in Python using negative indices. Retrieve and print the element at index -2.

# %% [markdown]
# Question 4:
# Access elements of a 2D array in Python and print a specific value. Retrieve and print the element at row 1, column 2.

# %% [markdown]
# Using Open Function and Basic Reading Function in Python
#
# Question 5:
# Use the open function to read a text file (wages_sample.csv) in Python. Print the content of the file.

# %%
# Out:
# [['\ufeffName', 'Age', 'Salary'], ['Alex', '34', '800'], ['Bob', '24', '900'], ['Sally', '22', '700'], ['Anna', '23', '1000']]

# %% [markdown]
# Question 6:
# Reterieve the names and salaries from the data list

# %%
# Out:
# Names: ['\ufeffName', 'Alex', 'Bob', 'Sally', 'Anna']
# Salaries: ['Salary', '800', '900', '700', '1000']

# %% [markdown]
# Question 7: Calculate the average of salary

# %%
# Out:
# 850.0

# %% [markdown]
# Question 9: Read CSV File using Open and Calculate number of words in each row

# %%
# Question 9: Read CSV File using Open and Calculate number of words in each row (without enumerate)

#change the path
csv_file_path = '/content/drive/MyDrive/........./sample_text.txt'

# Initialize a counter for line number
line_number = 0
# Out:
# Row 1 Number of words 59
# Row 2 Number of words 56

# %% [markdown]
# Question 10: modify Question 9 by adding the exception handling try-except if the file doesnt exist, it show a friendly message
