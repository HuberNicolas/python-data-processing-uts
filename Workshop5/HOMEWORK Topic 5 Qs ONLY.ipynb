# %% [markdown]
# Homework - Topic 5 python notebook:
# * Strings
# * List
# * Tuples
# * Dictionaries

# %%
#Question 1:
#Combine two strings (string_a and string_b) using string concatenation and print the result.

# %%
string_a = "Good"
string_b = "morning"

# %%
#Question 2: Determine and print the length of a given string (sentence).

# %%
#Question 3: Extract a substring (substring_example) from a given string (original_text) using slicing and print the result.

# %%
#Question 4: Check if a specified substring (search_word) exists in a given string (original_text) and print the result.

# %%
search_word = "Learning"

# %%
#Question 5: Create a list (fruits_list) with different fruit names and print the list.

# %%
#Question 6: Append a new element to the list (fruits_list) and remove a specific element. Print the list after each operation.

# %%
#Question 7: Iterate over the elements of the list (fruits_list) and print each element.

# %%
#Question 8: Create a tuple (days_of_week) with different days and print the tuple.

# %%
#Question 9: Perform an operation using the elements of the tuple (days_of_week) and print the result.

# %%
#Question 10: Create a dictionary (person_info) with key-value pairs representing information about a person and print the dictionary.

# %%
#Question 11: Add information about a new skill to the person's dictionary (person_info) and iterate over the key-value pairs to print them.

# %%
#Question 12: Prompt the user to enter details for multiple products, including product name, price, and quantity.
#Store this information in a list of dictionaries representing each product. Finally, display the list of products.

# %%
products_list = []
num_products = int(input("Enter the number of products: "))

# %%
# Question 13 Collect exam scores for a group of students using the input function. Add the scores to a dictionary,
#and then categorize each student based on their scores into predefined grade categories (A, B, C, D).

# %%
exam_scores = {}
num_students = int(input("Enter the number of students: "))

# %%
#Question 14: Create a tuple to store physical constants such as gravity acceleration, speed of light, and gravitational constant. Use these constants to perform a calculation,
#such as calculating the weight of an object based on mass and gravity acceleration.

# %%
physical_constants = (9.8, 299792458, 6.67430e-11)
print("Physical Constants:", physical_constants)
