# %% [markdown]
# Topic 5 python notebook:
# * Strings
# * List
# * Tuples
# * Dictionaries

# %%
#Question 1: Combine two strings (string1 and string2) using string concatenation and print the result.

# %%
string1 = "Hello"
string2 = "World"

# %%
concat_string = string1 + " " + string2
print(f"Resulting string after concatenating: {concat_string}")
# Out:
# Resulting string after concatenating: Hello World

# %%
#Question 2: Determine and print the length of a given string (my_string).

# %%
my_string = "Python is awesome!"

len_my_string = len(my_string)

print(f"The string {my_string} has length {len_my_string}.")
# Out:
# The string Python is awesome! has length 18.

# %%
#Question 3: Extract a substring (substring) from a given string (original_string) using slicing and print the result.

# %%
original_string = "Python Programming"

substring = original_string[-11:]
print(substring)
# Out:
# Programming

# %%
#Question 4: Check if a specified substring (search_string) exists in a given string (original_string) and print the result.

# %%
search_string = "Python"

index = original_string.find(search_string)


if index != -1: 
    print(f"Original string '{original_string}' contains substring '{substring}' at index {index}.")
else:
    print(f"Original string '{original_string}' does not contain the substring '{substring}'.")
# Out:
# Original string 'Python Programming' contains substring 'Programming' at index 0.

# %%
#Question 5: Create a list (my_list) with a few elements and print the list.

# %%
my_list = ['Alpha', 'Beta', 'Gamma']

# %%
#Question 6: Append a new element to the list (my_list) and remove a specific element. Print the list after each operation.

# %%
my_list.append("Delta")

print("Start printing the list after appending...")
for item in my_list:
    print(item)
print("Finished printing")
    

print("Start printing the list after removing...")    
my_list.remove("Beta")
for item in my_list:
    print(item)
print("Finished printing")
# Out:
# Start printing the list after appending...
# Alpha
# Beta
# Gamma
# Delta
# Finished printing
# Start printing the list after removing...
# Alpha
# Gamma
# Delta
# Finished printing

# %%
#Question 7: Iterate over the elements of the list (my_list) and print each element.

# %%
print("Start printing the list...")    
for item in my_list:
    print(item)
print("Finished printing")
# Out:
# Start printing the list...
# Alpha
# Gamma
# Delta
# Finished printing

# %%
#Question 8: Create a tuple (my_tuple) with a few elements and print the tuple.

# %%
my_tuple = ('a', 'b', 'c', 'd')

print(my_tuple)
# Out:
# ('a', 'b', 'c', 'd')

# %%
#Question 9: Create a dictionary (my_dict) with key-value pairs representing information about a person and print the dictionary.

# %%
my_dict = {"name": "Huber", "age": 27, "city": "Urdorf"}

print(my_dict)
# Out:
# {'name': 'Huber', 'age': 27, 'city': 'Urdorf'}

# %%
#Question 10: Update the information about a new person to the dictionary (my_dict) using update and iterate over the key-value pairs to print them.

# %%
new_person = {"name": "Alice", "age": 30, "city": "San Francisco"}
my_dict.update(new_person)

#iterate over the key-value pairs to print them


for key, value in my_dict.items():
    print(f"Key: {key}, Value: {value}")
# Out:
# Key: name, Value: Alice
# Key: age, Value: 30
# Key: city, Value: San Francisco

# %%
#Question 11: Use the input function to get salaries from users, add them to a list, and then calculate and print the average salary.

# %%
# Answer 11
salary_list = []
num_salaries = int(input("Enter the number of salaries: "))

#complete the code
for i in range(num_salaries):
    salary = int(input(f"Enter salary {i}: "))
    salary_list.append(salary)
    

average_salary = sum(salary_list) / len(salary_list)

print("Average Salary:", average_salary)
# Out:
# Average Salary: 2.5

# %%
# Question 12 Use input function to add marks to dictionary then count of the number of students who pass and fail
#make student name is the key and the mark is the value

# %%
# Question 12
marks_dict = {}
num_students = int(input("Enter the number of students: "))

for i in range(num_students):
    grade = str(input(f"Enter grade {i}: "))
    
    if grade in marks_dict.keys():
        marks_dict[grade] += 1
    
    else:
        marks_dict[grade] = 1


hd_count = marks_dict["HD"]
d_count = marks_dict["D"]
c_count = marks_dict["C"]
p_count = marks_dict["P"]
fail_count = marks_dict["Fail"]        

print("Grade Categories:")
print("HD:", hd_count)
print("D:", d_count)
print("C:", c_count)
print("P:", p_count)
print("Fails:", fail_count)
# Out:
# Grade Categories:
# HD: 1
# D: 1
# C: 1
# P: 1
# Fails: 1
